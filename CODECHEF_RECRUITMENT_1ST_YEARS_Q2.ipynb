# %% [markdown]
# <a href="https://colab.research.google.com/github/notsogood30/Sparks_foundation/blob/main/CODECHEF_RECRUITMENT_1ST_YEARS_Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exploratory Data Analysis: Assignment
# ## Describing the dataset

# %% [markdown]
# Dataset
# Haberman's Survival Data
#
# Description
# The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago’s Billings Hospital on the survival of patients who had undergone surgery for breast cancer.
#
# Attribute Information
# Column 1: Age of patient at the time of operation (numerical)
# Column 2: Patient's year of operation (year 1900 - numerical)
# Column 3: Number of positive axillary nodes detected (numerical)
# Column 4: Survival status (class attribute)
# 1 = the patient survived 5 years or longer
# 2 = the patient died within 5 years

# %% [markdown]
# ## Loading the dataset

# %% [markdown]
# ## PART 1: Understanding the dataset

# %% [markdown]
# Ques 1.1: Print the first 5 entries from the csv file
# Expected Output

# %%
from google.colab import files   
uploaded = files.upload()
# Out:
#      <input type="file" id="files-468d620b-11dc-4016-87e7-0fb3b767a4db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-468d620b-11dc-4016-87e7-0fb3b767a4db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haberman (1).csv to haberman (1).csv

# %%
import pandas as pd 
import io 
df = pd.read_csv(io.BytesIO(uploaded['haberman (1).csv']))
df.head()
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %% [markdown]
# ## Ques 1.2: How many data-points and features does the dataset have?

# %%
df.shape
# Out:
# (306, 4)

# %% [markdown]
# ## Ques 1.3: What are the column names in our dataset?

# %%
df.columns
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %% [markdown]
# ## Ques 1.4: How many data-points for each class of column 'status' are present?

# %%
df['status'].value_counts()
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %% [markdown]
# ## PART 2: Scatter Plot (2-D)
# ## Just run this code cell (Don't change anything)

# %%
# Scatter Plot without color grading
import matplotlib.pyplot as plt
df.plot(kind='scatter', x='age', y='year');
plt.show()

# OBSERVATION: Both the classes are of same color (blue) and thus cannot make much sense.

# %% [markdown]
# ## Ques 2.1: Color the points by their class-label/status-type

# %%
import seaborn as sns
sns.scatterplot(data=df, x="age", y="year", hue="status")
'''HINT: Use hue dimension of the Grid'''
# Out:
# 'HINT: Use hue dimension of the Grid'

# %% [markdown]
# ## Ques 2.2: Make 2 separate plots each of only 1 status-type in column dimension of the grid

# %%
sns.relplot(
    data=df, x="age", y="year",
    col="status", hue="nodes", style="nodes",
    kind="scatter"
)

# %% [markdown]
# ## PART 3: Pair Plots
# ## Ques 3.1: Plot the pairwise scatter plot with hue dimension of the grid

# %%
sns.pairplot(df,hue = 'status',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %% [markdown]
# ## PART 4: PDF and CDF
# ## Ques 4: Show the density plot with respect to the 'year' feature in 'row dimension' of the grid.

# %%
df.year.plot.density(figsize=(8,6))
